# %%
# Dependencies & Setup
import pandas as pd
import numpy as np
import datetime as dt

# %%
jan2019 = "Data/JC-201901-citibike-tripdata.csv"
jan2020 = "JData/C-202001-citibike-tripdata.csv"

# %%
jan2019_df = pd.read_csv(jan2019, encoding="ISO-8859-1")
jan2020_df = pd.read_csv(jan2020, encoding="ISO-8859-1")

# %%
combojandf = jan2019_df.append([jan2020_df], ignore_index=True)
combojandf.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
# Rename Columns
renamecombojandf = combojandf.rename(columns={"tripduration": "Trip Duration",
                                            "starttime": "Start Time",
                                            "stoptime": "Stop Time",
                                            "start station id": "Start Station ID",
                                            "start station name": "Start Station Name",
                                            "start station latitude": "Start Station Latitude",
                                            "start station longitude": "Start Station Longitude",
                                            "end station id": "End Station ID",
                                            "end station name": "End Station Name",
                                            "end station latitude": "End Station Latitude",
                                            "end station longitude": "End Station Longitude",
                                            "bikeid": "Bike ID",
                                            "usertype": "User Type",
                                            "birth year": "Birth Year",
                                            "gender": "Gender"
                                           })
renamecombojandf.head()
# Out:
#    Trip Duration                Start Time                 Stop Time  \
# 0            201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1            505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2            756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3           1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4           1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    Start Station ID Start Station Name  Start Station Latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    Start Station Longitude  End Station ID    End Station Name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
# Convert All DateTimes to "%Y-%m-%d %H:%M:%S" Format
renamecombojandf["Start Time"] = pd.to_datetime(renamecombojandf["Start Time"])
renamecombojandf["Stop Time"] = pd.to_datetime(renamecombojandf["Stop Time"])
renamecombojandf.head()
# Out:
#    Trip Duration              Start Time               Stop Time  \
# 0            201 2019-01-01 03:09:09.711 2019-01-01 03:12:30.879
# 1            505 2019-01-01 05:18:00.106 2019-01-01 05:26:25.905
# 2            756 2019-01-01 10:36:33.340 2019-01-01 10:49:10.260
# 3           1575 2019-01-01 12:43:38.643 2019-01-01 13:09:54.528
# 4           1566 2019-01-01 12:43:39.601 2019-01-01 13:09:46.510
#
#    Start Station ID Start Station Name  Start Station Latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    Start Station Longitude  End Station ID    End Station Name  \
# 0               -74.033459            3214    Essex Light Rail
# 1               -74.033459            3638       Washington St
# ...

# %%
renamecombojandf.to_csv("citibike-tripdataJan19-20.csv", index=False, header=True)

# %%
feb2019 = "Data/JC-201902-citibike-tripdata.csv"
feb2020 = "Data/JC-202002-citibike-tripdata.csv"

# %%
feb2019_df = pd.read_csv(feb2019, encoding="ISO-8859-1")
feb2020_df = pd.read_csv(feb2020, encoding="ISO-8859-1")

# %%
combofebdf = feb2019_df.append([feb2020_df], ignore_index=True)
combofebdf.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           142  2019-02-01 15:35:02.0820  2019-02-01 15:37:24.1360
# 1           223  2019-02-01 17:00:46.8900  2019-02-01 17:04:30.5500
# 2           106  2019-02-01 17:08:01.3260  2019-02-01 17:09:47.4400
# 3           370  2019-02-01 17:09:31.2100  2019-02-01 17:15:41.6550
# 4           315  2019-02-01 17:19:53.2490  2019-02-01 17:25:09.1400
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3639       Harborside
# ...

# %%
# Rename Columns
renamecombofebdf = combofebdf.rename(columns={"tripduration": "Trip Duration",
                                            "starttime": "Start Time",
                                            "stoptime": "Stop Time",
                                            "start station id": "Start Station ID",
                                            "start station name": "Start Station Name",
                                            "start station latitude": "Start Station Latitude",
                                            "start station longitude": "Start Station Longitude",
                                            "end station id": "End Station ID",
                                            "end station name": "End Station Name",
                                            "end station latitude": "End Station Latitude",
                                            "end station longitude": "End Station Longitude",
                                            "bikeid": "Bike ID",
                                            "usertype": "User Type",
                                            "birth year": "Birth Year",
                                            "gender": "Gender"
                                           })
renamecombofebdf.head()
# Out:
#    Trip Duration                Start Time                 Stop Time  \
# 0            142  2019-02-01 15:35:02.0820  2019-02-01 15:37:24.1360
# 1            223  2019-02-01 17:00:46.8900  2019-02-01 17:04:30.5500
# 2            106  2019-02-01 17:08:01.3260  2019-02-01 17:09:47.4400
# 3            370  2019-02-01 17:09:31.2100  2019-02-01 17:15:41.6550
# 4            315  2019-02-01 17:19:53.2490  2019-02-01 17:25:09.1400
#
#    Start Station ID Start Station Name  Start Station Latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    Start Station Longitude  End Station ID End Station Name  \
# 0               -74.033459            3639       Harborside
# ...

# %%
renamecombofebdf["Start Time"] = pd.to_datetime(renamecombofebdf["Start Time"])
renamecombofebdf["Stop Time"] = pd.to_datetime(renamecombofebdf["Stop Time"])
renamecombofebdf.head()
# Out:
#    Trip Duration              Start Time               Stop Time  \
# 0            142 2019-02-01 15:35:02.082 2019-02-01 15:37:24.136
# 1            223 2019-02-01 17:00:46.890 2019-02-01 17:04:30.550
# 2            106 2019-02-01 17:08:01.326 2019-02-01 17:09:47.440
# 3            370 2019-02-01 17:09:31.210 2019-02-01 17:15:41.655
# 4            315 2019-02-01 17:19:53.249 2019-02-01 17:25:09.140
#
#    Start Station ID Start Station Name  Start Station Latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    Start Station Longitude  End Station ID End Station Name  \
# 0               -74.033459            3639       Harborside
# 1               -74.033459            3681         Grand St
# ...

# %%
renamecombofebdf.to_csv("citibike-tripdataFeb19-20.csv", index=False, header=True)

# %%
mar2019 = "Data/JC-201903-citibike-tripdata.csv"
mar2020 = "Data/JC-202003-citibike-tripdata.csv"

# %%
mar2019_df = pd.read_csv(mar2019, encoding="ISO-8859-1")
mar2020_df = pd.read_csv(mar2020, encoding="ISO-8859-1")

# %%
combomardf = mar2019_df.append([mar2020_df], ignore_index=True)
combomardf.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           306  2019-03-01 06:47:08.2110  2019-03-01 06:52:14.7150
# 1           123  2019-03-01 07:30:53.0220  2019-03-01 07:32:56.7770
# 2           328  2019-03-01 08:18:30.4030  2019-03-01 08:23:59.0590
# 3            95  2019-03-01 11:04:47.2020  2019-03-01 11:06:22.8130
# 4           169  2019-03-01 11:51:29.4170  2019-03-01 11:54:19.2120
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3267     Morris Canal
# ...

# %%
# Rename Columns
renamecombomardf = combomardf.rename(columns={"tripduration": "Trip Duration",
                                            "starttime": "Start Time",
                                            "stoptime": "Stop Time",
                                            "start station id": "Start Station ID",
                                            "start station name": "Start Station Name",
                                            "start station latitude": "Start Station Latitude",
                                            "start station longitude": "Start Station Longitude",
                                            "end station id": "End Station ID",
                                            "end station name": "End Station Name",
                                            "end station latitude": "End Station Latitude",
                                            "end station longitude": "End Station Longitude",
                                            "bikeid": "Bike ID",
                                            "usertype": "User Type",
                                            "birth year": "Birth Year",
                                            "gender": "Gender"
                                           })
renamecombomardf.head()
# Out:
#    Trip Duration                Start Time                 Stop Time  \
# 0            306  2019-03-01 06:47:08.2110  2019-03-01 06:52:14.7150
# 1            123  2019-03-01 07:30:53.0220  2019-03-01 07:32:56.7770
# 2            328  2019-03-01 08:18:30.4030  2019-03-01 08:23:59.0590
# 3             95  2019-03-01 11:04:47.2020  2019-03-01 11:06:22.8130
# 4            169  2019-03-01 11:51:29.4170  2019-03-01 11:54:19.2120
#
#    Start Station ID Start Station Name  Start Station Latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    Start Station Longitude  End Station ID End Station Name  \
# 0               -74.033459            3267     Morris Canal
# ...

# %%
# Convert All DateTimes to "%Y-%m-%d %H:%M:%S" Format
renamecombomardf["Start Time"] = pd.to_datetime(renamecombomardf["Start Time"])
renamecombomardf["Stop Time"] = pd.to_datetime(renamecombomardf["Stop Time"])
renamecombomardf.head()
# Out:
#    Trip Duration              Start Time               Stop Time  \
# 0            306 2019-03-01 06:47:08.211 2019-03-01 06:52:14.715
# 1            123 2019-03-01 07:30:53.022 2019-03-01 07:32:56.777
# 2            328 2019-03-01 08:18:30.403 2019-03-01 08:23:59.059
# 3             95 2019-03-01 11:04:47.202 2019-03-01 11:06:22.813
# 4            169 2019-03-01 11:51:29.417 2019-03-01 11:54:19.212
#
#    Start Station ID Start Station Name  Start Station Latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    Start Station Longitude  End Station ID End Station Name  \
# 0               -74.033459            3267     Morris Canal
# 1               -74.033459            3184      Paulus Hook
# ...

# %%
# Save Combined DataFrames to CSV
renamecombomardf.to_csv("citibike-tripdataMar19-20.csv", index=False, header=True)

# %%
apr2019 = "Data/JC-201904-citibike-tripdata.csv"
apr2020 = "Data/JC-202004-citibike-tripdata.csv"

# %%
apr2019_df = pd.read_csv(apr2019, encoding="ISO-8859-1")
apr2020_df = pd.read_csv(apr2020, encoding="ISO-8859-1")

# %%
comboaprdf = apr2019_df.append([apr2020_df], ignore_index=True)
comboaprdf.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1           493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2           512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3           196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4           463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
# Rename Columns
renamecomboaprdf = comboaprdf.rename(columns={"tripduration": "Trip Duration",
                                            "starttime": "Start Time",
                                            "stoptime": "Stop Time",
                                            "start station id": "Start Station ID",
                                            "start station name": "Start Station Name",
                                            "start station latitude": "Start Station Latitude",
                                            "start station longitude": "Start Station Longitude",
                                            "end station id": "End Station ID",
                                            "end station name": "End Station Name",
                                            "end station latitude": "End Station Latitude",
                                            "end station longitude": "End Station Longitude",
                                            "bikeid": "Bike ID",
                                            "usertype": "User Type",
                                            "birth year": "Birth Year",
                                            "gender": "Gender"
                                           })
renamecomboaprdf.head()
# Out:
#    Trip Duration                Start Time                 Stop Time  \
# 0            107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1            493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2            512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3            196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4            463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    Start Station ID Start Station Name  Start Station Latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    Start Station Longitude  End Station ID  End Station Name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
# Convert All DateTimes to "%Y-%m-%d %H:%M:%S" Format
renamecomboaprdf["Start Time"] = pd.to_datetime(renamecomboaprdf["Start Time"])
renamecomboaprdf["Stop Time"] = pd.to_datetime(renamecomboaprdf["Stop Time"])
renamecomboaprdf.head()
# Out:
#    Trip Duration              Start Time               Stop Time  \
# 0            107 2019-04-01 07:48:04.754 2019-04-01 07:49:52.359
# 1            493 2019-04-01 12:41:09.654 2019-04-01 12:49:23.029
# 2            512 2019-04-01 14:27:07.940 2019-04-01 14:35:40.937
# 3            196 2019-04-01 15:07:38.151 2019-04-01 15:10:54.626
# 4            463 2019-04-01 16:19:24.694 2019-04-01 16:27:08.645
#
#    Start Station ID Start Station Name  Start Station Latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    Start Station Longitude  End Station ID  End Station Name  \
# 0               -74.033459            3184       Paulus Hook
# 1               -74.033459            3187         Warren St
# ...

# %%
renamecomboaprdf.to_csv("citibike-tripdataApr19-20.csv", index=False, header=True)

# %%
may2019 = "Data/JC-201905-citibike-tripdata.csv"
may2020 = "Data/JC-202005-citibike-tripdata.csv"

# %%
may2019_df = pd.read_csv(may2019, encoding="ISO-8859-1")
may2020_df = pd.read_csv(may2020, encoding="ISO-8859-1")

# %%
combomaydf = may2019_df.append([may2020_df], ignore_index=True)
combomaydf.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           311  2019-05-01 00:07:36.4670  2019-05-01 00:12:47.6350
# 1           538  2019-05-01 00:08:29.2840  2019-05-01 00:17:27.9410
# 2           178  2019-05-01 00:39:36.4750  2019-05-01 00:42:34.9640
# 3           317  2019-05-01 01:24:28.0220  2019-05-01 01:29:45.5730
# 4           354  2019-05-01 01:54:39.6660  2019-05-01 02:00:34.1750
#
#    start station id start station name  start station latitude  \
# 0              3185          City Hall               40.717732
# 1              3681           Grand St               40.715178
# 2              3638      Washington St               40.724294
# 3              3206            Hilltop               40.731169
# 4              3639         Harborside               40.719252
#
#    start station longitude  end station id end station name  \
# 0               -74.043845            3279      Dixon Mills
# ...

# %%
# Rename Columns
renamecombomaydf = combomaydf.rename(columns={"tripduration": "Trip Duration",
                                            "starttime": "Start Time",
                                            "stoptime": "Stop Time",
                                            "start station id": "Start Station ID",
                                            "start station name": "Start Station Name",
                                            "start station latitude": "Start Station Latitude",
                                            "start station longitude": "Start Station Longitude",
                                            "end station id": "End Station ID",
                                            "end station name": "End Station Name",
                                            "end station latitude": "End Station Latitude",
                                            "end station longitude": "End Station Longitude",
                                            "bikeid": "Bike ID",
                                            "usertype": "User Type",
                                            "birth year": "Birth Year",
                                            "gender": "Gender"
                                           })
renamecombomaydf.head()
# Out:
#    Trip Duration                Start Time                 Stop Time  \
# 0            311  2019-05-01 00:07:36.4670  2019-05-01 00:12:47.6350
# 1            538  2019-05-01 00:08:29.2840  2019-05-01 00:17:27.9410
# 2            178  2019-05-01 00:39:36.4750  2019-05-01 00:42:34.9640
# 3            317  2019-05-01 01:24:28.0220  2019-05-01 01:29:45.5730
# 4            354  2019-05-01 01:54:39.6660  2019-05-01 02:00:34.1750
#
#    Start Station ID Start Station Name  Start Station Latitude  \
# 0              3185          City Hall               40.717732
# 1              3681           Grand St               40.715178
# 2              3638      Washington St               40.724294
# 3              3206            Hilltop               40.731169
# 4              3639         Harborside               40.719252
#
#    Start Station Longitude  End Station ID End Station Name  \
# 0               -74.043845            3279      Dixon Mills
# ...

# %%
# Convert All DateTimes to "%Y-%m-%d %H:%M:%S" Format
renamecombomaydf["Start Time"] = pd.to_datetime(renamecombomaydf["Start Time"])
renamecombomaydf["Stop Time"] = pd.to_datetime(renamecombomaydf["Stop Time"])
renamecombomaydf.head()
# Out:
#    Trip Duration              Start Time               Stop Time  \
# 0            311 2019-05-01 00:07:36.467 2019-05-01 00:12:47.635
# 1            538 2019-05-01 00:08:29.284 2019-05-01 00:17:27.941
# 2            178 2019-05-01 00:39:36.475 2019-05-01 00:42:34.964
# 3            317 2019-05-01 01:24:28.022 2019-05-01 01:29:45.573
# 4            354 2019-05-01 01:54:39.666 2019-05-01 02:00:34.175
#
#    Start Station ID Start Station Name  Start Station Latitude  \
# 0              3185          City Hall               40.717732
# 1              3681           Grand St               40.715178
# 2              3638      Washington St               40.724294
# 3              3206            Hilltop               40.731169
# 4              3639         Harborside               40.719252
#
#    Start Station Longitude  End Station ID End Station Name  \
# 0               -74.043845            3279      Dixon Mills
# 1               -74.037683            3203    Hamilton Park
# ...

# %%
jun2019 = "Data/JC-201906-citibike-tripdata.csv"
jun2020 = "Data/JC-202006-citibike-tripdata.csv"

# %%
jun2019_df = pd.read_csv(jun2019, encoding="ISO-8859-1")
jun2020_df = pd.read_csv(jun2020, encoding="ISO-8859-1")

# %%
combojundf = jun2019_df.append([jun2020_df], ignore_index=True)
combojundf.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1           280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 2          2162  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640
# 3          2184  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250
# 4           139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
#
#    start station id start station name  start station latitude  \
# 0              3187          Warren St               40.721124
# 1              3185          City Hall               40.717732
# 2              3199       Newport Pkwy               40.728745
# 3              3199       Newport Pkwy               40.728745
# 4              3207        Oakland Ave               40.737604
#
#    start station longitude  end station id end station name  \
# 0               -74.038051            3199     Newport Pkwy
# ...

# %%
# Rename Columns
renamecombojundf = combojundf.rename(columns={"tripduration": "Trip Duration",
                                            "starttime": "Start Time",
                                            "stoptime": "Stop Time",
                                            "start station id": "Start Station ID",
                                            "start station name": "Start Station Name",
                                            "start station latitude": "Start Station Latitude",
                                            "start station longitude": "Start Station Longitude",
                                            "end station id": "End Station ID",
                                            "end station name": "End Station Name",
                                            "end station latitude": "End Station Latitude",
                                            "end station longitude": "End Station Longitude",
                                            "bikeid": "Bike ID",
                                            "usertype": "User Type",
                                            "birth year": "Birth Year",
                                            "gender": "Gender"
                                           })
renamecombojundf.head()
# Out:
#    Trip Duration                Start Time                 Stop Time  \
# 0            316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1            280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 2           2162  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640
# 3           2184  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250
# 4            139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
#
#    Start Station ID Start Station Name  Start Station Latitude  \
# 0              3187          Warren St               40.721124
# 1              3185          City Hall               40.717732
# 2              3199       Newport Pkwy               40.728745
# 3              3199       Newport Pkwy               40.728745
# 4              3207        Oakland Ave               40.737604
#
#    Start Station Longitude  End Station ID End Station Name  \
# 0               -74.038051            3199     Newport Pkwy
# ...

# %%
# Convert All DateTimes to "%Y-%m-%d %H:%M:%S" Format
renamecombojundf["Start Time"] = pd.to_datetime(renamecombojundf["Start Time"])
renamecombojundf["Stop Time"] = pd.to_datetime(renamecombojundf["Stop Time"])
renamecombojundf.head()
# Out:
#    Trip Duration              Start Time               Stop Time  \
# 0            316 2019-06-01 00:05:55.721 2019-06-01 00:11:11.994
# 1            280 2019-06-01 00:08:09.092 2019-06-01 00:12:50.073
# 2           2162 2019-06-01 00:13:11.880 2019-06-01 00:49:14.364
# 3           2184 2019-06-01 00:13:30.111 2019-06-01 00:49:54.225
# 4            139 2019-06-01 00:13:31.852 2019-06-01 00:15:51.788
#
#    Start Station ID Start Station Name  Start Station Latitude  \
# 0              3187          Warren St               40.721124
# 1              3185          City Hall               40.717732
# 2              3199       Newport Pkwy               40.728745
# 3              3199       Newport Pkwy               40.728745
# 4              3207        Oakland Ave               40.737604
#
#    Start Station Longitude  End Station ID End Station Name  \
# 0               -74.038051            3199     Newport Pkwy
# 1               -74.043845            3267     Morris Canal
# ...

# %%
jul2019 = "Data/JC-201907-citibike-tripdata.csv"
jul2020 = "Data/JC-202007-citibike-tripdata.csv"

# %%
jul2019_df = pd.read_csv(jul2019, encoding="ISO-8859-1")
jul2020_df = pd.read_csv(jul2020, encoding="ISO-8859-1")

# %%
combojuldf = jul2019_df.append([jul2020_df], ignore_index=True)
combojuldf.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1793  2019-07-01 00:00:36.6150  2019-07-01 00:30:30.5940
# 1           434  2019-07-01 00:02:54.6150  2019-07-01 00:10:09.0370
# 2           251  2019-07-01 00:03:27.5670  2019-07-01 00:07:38.6080
# 3           636  2019-07-01 00:03:56.1690  2019-07-01 00:14:32.4180
# 4           623  2019-07-01 00:04:16.2060  2019-07-01 00:14:40.0500
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3206            Hilltop               40.731169
# 2              3186      Grove St PATH               40.719586
# 3              3206            Hilltop               40.731169
# 4              3206            Hilltop               40.731169
#
#    start station longitude  end station id     end station name  \
# 0               -74.043117            3198     Heights Elevator
# ...

# %%
# Rename Columns
renamecombojuldf = combojuldf.rename(columns={"tripduration": "Trip Duration",
                                            "starttime": "Start Time",
                                            "stoptime": "Stop Time",
                                            "start station id": "Start Station ID",
                                            "start station name": "Start Station Name",
                                            "start station latitude": "Start Station Latitude",
                                            "start station longitude": "Start Station Longitude",
                                            "end station id": "End Station ID",
                                            "end station name": "End Station Name",
                                            "end station latitude": "End Station Latitude",
                                            "end station longitude": "End Station Longitude",
                                            "bikeid": "Bike ID",
                                            "usertype": "User Type",
                                            "birth year": "Birth Year",
                                            "gender": "Gender"
                                           })
renamecombojuldf.head()
# Out:
#    Trip Duration                Start Time                 Stop Time  \
# 0           1793  2019-07-01 00:00:36.6150  2019-07-01 00:30:30.5940
# 1            434  2019-07-01 00:02:54.6150  2019-07-01 00:10:09.0370
# 2            251  2019-07-01 00:03:27.5670  2019-07-01 00:07:38.6080
# 3            636  2019-07-01 00:03:56.1690  2019-07-01 00:14:32.4180
# 4            623  2019-07-01 00:04:16.2060  2019-07-01 00:14:40.0500
#
#    Start Station ID Start Station Name  Start Station Latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3206            Hilltop               40.731169
# 2              3186      Grove St PATH               40.719586
# 3              3206            Hilltop               40.731169
# 4              3206            Hilltop               40.731169
#
#    Start Station Longitude  End Station ID     End Station Name  \
# 0               -74.043117            3198     Heights Elevator
# ...

# %%
# Convert All DateTimes to "%Y-%m-%d %H:%M:%S" Format
renamecombojuldf["Start Time"] = pd.to_datetime(renamecombojuldf["Start Time"])
renamecombojuldf["Stop Time"] = pd.to_datetime(renamecombojuldf["Stop Time"])
renamecombojuldf.head()
# Out:
#    Trip Duration              Start Time               Stop Time  \
# 0           1793 2019-07-01 00:00:36.615 2019-07-01 00:30:30.594
# 1            434 2019-07-01 00:02:54.615 2019-07-01 00:10:09.037
# 2            251 2019-07-01 00:03:27.567 2019-07-01 00:07:38.608
# 3            636 2019-07-01 00:03:56.169 2019-07-01 00:14:32.418
# 4            623 2019-07-01 00:04:16.206 2019-07-01 00:14:40.050
#
#    Start Station ID Start Station Name  Start Station Latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3206            Hilltop               40.731169
# 2              3186      Grove St PATH               40.719586
# 3              3206            Hilltop               40.731169
# 4              3206            Hilltop               40.731169
#
#    Start Station Longitude  End Station ID     End Station Name  \
# 0               -74.043117            3198     Heights Elevator
# ...

# %%
aug2019 = "Data/JC-201908-citibike-tripdata.csv"
aug2020 = "Data/JC-202008-citibike-tripdata.csv"

# %%
aug2019_df = pd.read_csv(aug2019, encoding="ISO-8859-1")
aug2020_df = pd.read_csv(aug2020, encoding="ISO-8859-1")

# %%
comboaugdf = aug2019_df.append([aug2020_df], ignore_index=True)

# %%
renamecomboaugdf = comboaugdf.rename(columns={"tripduration": "Trip Duration",
                                            "starttime": "Start Time",
                                            "stoptime": "Stop Time",
                                            "start station id": "Start Station ID",
                                            "start station name": "Start Station Name",
                                            "start station latitude": "Start Station Latitude",
                                            "start station longitude": "Start Station Longitude",
                                            "end station id": "End Station ID",
                                            "end station name": "End Station Name",
                                            "end station latitude": "End Station Latitude",
                                            "end station longitude": "End Station Longitude",
                                            "bikeid": "Bike ID",
                                            "usertype": "User Type",
                                            "birth year": "Birth Year",
                                            "gender": "Gender"
                                           })

# %%
renamecomboaugdf["Start Time"] = pd.to_datetime(renamecomboaugdf["Start Time"])
renamecomboaugdf["Stop Time"] = pd.to_datetime(renamecomboaugdf["Stop Time"])

# %%
sep2019 = "Data/JC-201909-citibike-tripdata.csv"
sep2020 = "Data/JC-202009-citibike-tripdata.csv"

# %%
sep2019_df = pd.read_csv(sep2019, encoding="ISO-8859-1")
sep2020_df = pd.read_csv(sep2020, encoding="ISO-8859-1")

# %%
combosepdf = sep2019_df.append([sep2020_df], ignore_index=True)

# %%
renamecombosepdf = combosepdf.rename(columns={"tripduration": "Trip Duration",
                                            "starttime": "Start Time",
                                            "stoptime": "Stop Time",
                                            "start station id": "Start Station ID",
                                            "start station name": "Start Station Name",
                                            "start station latitude": "Start Station Latitude",
                                            "start station longitude": "Start Station Longitude",
                                            "end station id": "End Station ID",
                                            "end station name": "End Station Name",
                                            "end station latitude": "End Station Latitude",
                                            "end station longitude": "End Station Longitude",
                                            "bikeid": "Bike ID",
                                            "usertype": "User Type",
                                            "birth year": "Birth Year",
                                            "gender": "Gender"
                                           })

# %%
renamecombosepdf["Start Time"] = pd.to_datetime(renamecombosepdf["Start Time"])
renamecombosepdf["Stop Time"] = pd.to_datetime(renamecombosepdf["Stop Time"])

# %%
oct2019 = "Data/JC-201910-citibike-tripdata.csv"
oct2020 = "Data/JC-202010-citibike-tripdata.csv"

# %%
oct2019_df = pd.read_csv(oct2019, encoding="ISO-8859-1")
oct2020_df = pd.read_csv(oct2020, encoding="ISO-8859-1")

# %%
combooctdf = oct2019_df.append([oct2020_df], ignore_index=True)

# %%
renamecombooctdf = combooctdf.rename(columns={"tripduration": "Trip Duration",
                                            "starttime": "Start Time",
                                            "stoptime": "Stop Time",
                                            "start station id": "Start Station ID",
                                            "start station name": "Start Station Name",
                                            "start station latitude": "Start Station Latitude",
                                            "start station longitude": "Start Station Longitude",
                                            "end station id": "End Station ID",
                                            "end station name": "End Station Name",
                                            "end station latitude": "End Station Latitude",
                                            "end station longitude": "End Station Longitude",
                                            "bikeid": "Bike ID",
                                            "usertype": "User Type",
                                            "birth year": "Birth Year",
                                            "gender": "Gender"
                                           })

# %%
renamecombooctdf["Start Time"] = pd.to_datetime(renamecombooctdf["Start Time"])
renamecombooctdf["Stop Time"] = pd.to_datetime(renamecombooctdf["Stop Time"])

# %%
nov2019 = "Data/JC-201911-citibike-tripdata.csv"
nov2020 = "Data/JC-202011-citibike-tripdata.csv"

# %%
nov2019_df = pd.read_csv(nov2019, encoding="ISO-8859-1")
nov2020_df = pd.read_csv(nov2020, encoding="ISO-8859-1")

# %%
combonovdf = nov2019_df.append([nov2020_df], ignore_index=True)

# %%
renamecombonovdf = combonovdf.rename(columns={"tripduration": "Trip Duration",
                                            "starttime": "Start Time",
                                            "stoptime": "Stop Time",
                                            "start station id": "Start Station ID",
                                            "start station name": "Start Station Name",
                                            "start station latitude": "Start Station Latitude",
                                            "start station longitude": "Start Station Longitude",
                                            "end station id": "End Station ID",
                                            "end station name": "End Station Name",
                                            "end station latitude": "End Station Latitude",
                                            "end station longitude": "End Station Longitude",
                                            "bikeid": "Bike ID",
                                            "usertype": "User Type",
                                            "birth year": "Birth Year",
                                            "gender": "Gender"
                                           })

# %%
renamecombonovdf["Start Time"] = pd.to_datetime(renamecombonovdf["Start Time"])
renamecombonovdf["Stop Time"] = pd.to_datetime(renamecombonovdf["Stop Time"])

# %%
dec2019 = "Data/JC-201912-citibike-tripdata.csv"
dec2020 = "Data/JC-202012-citibike-tripdata.csv"

# %%
dec2019_df = pd.read_csv(dec2019, encoding="ISO-8859-1")
dec2020_df = pd.read_csv(dec2020, encoding="ISO-8859-1")

# %%
combodecdf = dec2019_df.append([nov2020_df], ignore_index=True)

# %%
renamecombodecdf = combodecdf.rename(columns={"tripduration": "Trip Duration",
                                            "starttime": "Start Time",
                                            "stoptime": "Stop Time",
                                            "start station id": "Start Station ID",
                                            "start station name": "Start Station Name",
                                            "start station latitude": "Start Station Latitude",
                                            "start station longitude": "Start Station Longitude",
                                            "end station id": "End Station ID",
                                            "end station name": "End Station Name",
                                            "end station latitude": "End Station Latitude",
                                            "end station longitude": "End Station Longitude",
                                            "bikeid": "Bike ID",
                                            "usertype": "User Type",
                                            "birth year": "Birth Year",
                                            "gender": "Gender"
                                           })

# %%
renamecombodecdf["Start Time"] = pd.to_datetime(renamecombodecdf["Start Time"])
renamecombodecdf["Stop Time"] = pd.to_datetime(renamecombodecdf["Stop Time"])

# %%
citibike_df = dec2020_df.append([jan2020_df,feb2020_df,mar2020_df,apr2020_df,may2020_df,jun2020_df,jul2020_df,
                                aug2020_df,sep2020_df,oct2020_df,nov2020_df])
citibike_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               146  2020-12-01 00:02:50.1450  2020-12-01 00:05:16.1940
# 1               572  2020-12-01 00:11:57.3910  2020-12-01 00:21:30.2510
# 2               387  2020-12-01 00:14:49.3610  2020-12-01 00:21:16.8730
# 3               188  2020-12-01 00:45:06.3680  2020-12-01 00:48:14.4280
# 4               594  2020-12-01 01:17:17.0110  2020-12-01 01:27:11.9400
# ...             ...                       ...                       ...
# 21270           849  2020-11-30 23:08:40.1870  2020-11-30 23:22:50.0830
# 21271           370  2020-11-30 23:09:27.0180  2020-11-30 23:15:37.3330
# 21272           341  2020-11-30 23:37:53.0580  2020-11-30 23:43:34.1200
# 21273          5272  2020-11-30 23:49:31.8650  2020-12-01 01:17:24.2540
# 21274           222  2020-11-30 23:56:52.8310  2020-12-01 00:00:34.8660
#
#        start station id start station name  start station latitude  \
# ...

# %%
citibike_df = citibike_df.rename(columns={"tripduration": "Trip Duration",
                                            "starttime": "Start Time",
                                            "stoptime": "Stop Time",
                                            "start station id": "Start Station ID",
                                            "start station name": "Start Station Name",
                                            "start station latitude": "Start Station Latitude",
                                            "start station longitude": "Start Station Longitude",
                                            "end station id": "End Station ID",
                                            "end station name": "End Station Name",
                                            "end station latitude": "End Station Latitude",
                                            "end station longitude": "End Station Longitude",
                                            "bikeid": "Bike ID",
                                            "usertype": "User Type",
                                            "birth year": "Birth Year",
                                            "gender": "Gender"
                                           })
citibike_df.head()
# Out:
#    Trip Duration                Start Time                 Stop Time  \
# 0            146  2020-12-01 00:02:50.1450  2020-12-01 00:05:16.1940
# 1            572  2020-12-01 00:11:57.3910  2020-12-01 00:21:30.2510
# 2            387  2020-12-01 00:14:49.3610  2020-12-01 00:21:16.8730
# 3            188  2020-12-01 00:45:06.3680  2020-12-01 00:48:14.4280
# 4            594  2020-12-01 01:17:17.0110  2020-12-01 01:27:11.9400
#
#    Start Station ID Start Station Name  Start Station Latitude  \
# 0              3202       Newport PATH               40.727224
# 1              3640     Journal Square               40.733670
# 2              3640     Journal Square               40.733670
# 3              3186      Grove St PATH               40.719586
# 4              3212    Christ Hospital               40.734786
#
#    Start Station Longitude  End Station ID End Station Name  \
# 0               -74.033759            3199     Newport Pkwy
# ...

# %%
# Convert All DateTimes to "%Y-%m-%d %H:%M:%S" Format
citibike_df["Start Time"] = pd.to_datetime(citibike_df["Start Time"])
citibike_df["Stop Time"] = pd.to_datetime(citibike_df["Stop Time"])
citibike_df.head
# Out:
# <bound method NDFrame.head of        Trip Duration              Start Time               Stop Time  \
# 0                146 2020-12-01 00:02:50.145 2020-12-01 00:05:16.194
# 1                572 2020-12-01 00:11:57.391 2020-12-01 00:21:30.251
# 2                387 2020-12-01 00:14:49.361 2020-12-01 00:21:16.873
# 3                188 2020-12-01 00:45:06.368 2020-12-01 00:48:14.428
# 4                594 2020-12-01 01:17:17.011 2020-12-01 01:27:11.940
# ...              ...                     ...                     ...
# 21270            849 2020-11-30 23:08:40.187 2020-11-30 23:22:50.083
# 21271            370 2020-11-30 23:09:27.018 2020-11-30 23:15:37.333
# 21272            341 2020-11-30 23:37:53.058 2020-11-30 23:43:34.120
# 21273           5272 2020-11-30 23:49:31.865 2020-12-01 01:17:24.254
# 21274            222 2020-11-30 23:56:52.831 2020-12-01 00:00:34.866
#
#        Start Station ID Start Station Name  Start Station Latitude  \
# ...

# %%
citibike_df.to_csv("citibike-tripdata2020.csv", index=False, header=True)
